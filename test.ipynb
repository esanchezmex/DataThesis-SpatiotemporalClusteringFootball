# %%
import pandas as pd

# %%
df = pd.read_parquet('match_2006551.parquet')

# %%
pd.set_option('display.max_columns', None)
df.head(20)
# Out:
#     skillcorner_match_id  frame_number  period  timestamp  minute  seconds  \
# 0                2006551            50       1        0.0       0      0.0
# 1                2006551            50       1        0.0       0      0.0
# 2                2006551            50       1        0.0       0      0.0
# 3                2006551            50       1        0.0       0      0.0
# 4                2006551            50       1        0.0       0      0.0
# 5                2006551            50       1        0.0       0      0.0
# 6                2006551            50       1        0.0       0      0.0
# 7                2006551            50       1        0.0       0      0.0
# 8                2006551            50       1        0.0       0      0.0
# 9                2006551            50       1        0.0       0      0.0
# 10               2006551            50       1        0.0       0      0.0
# ...

# %%
df.columns.tolist()
# Out:
# ['skillcorner_match_id',
#  'frame_number',
#  'period',
#  'timestamp',
#  'minute',
#  'seconds',
#  'player_id',
#  'x',
#  'y',
#  'is_detected',
#  'ball_x',
#  'ball_y',
#  'ball_z',
#  'ball_is_detected',
#  'team',
#  'player_name',
#  'number',
#  'role_name',
#  'role_line',
#  '50_50',
#  'bad_behaviour_card',
#  'ball_receipt_outcome',
#  'ball_recovery_recovery_failure',
#  'block_deflection',
#  'block_offensive',
#  'carry_end_location',
#  'clearance_aerial_won',
#  'clearance_body_part',
#  'clearance_head',
#  'clearance_left_foot',
#  'clearance_right_foot',
#  'counterpress',
#  'dribble_no_touch',
#  'dribble_outcome',
#  'duel_outcome',
#  'duel_type',
#  'duration',
#  'foul_committed_advantage',
#  'foul_committed_card',
#  'foul_committed_offensive',
#  'foul_committed_type',
#  'foul_won_advantage',
#  'foul_won_defensive',
#  'goalkeeper_body_part',
#  'goalkeeper_end_location',
#  'goalkeeper_outcome',
#  'goalkeeper_position',
#  'goalkeeper_technique',
# ...

# %%
df[df['type'] == 'Shot'].groupby('possession').count()
# Out:
#             skillcorner_match_id  frame_number  period  timestamp  minute  \
# possession
# 12.0                         110           110     110        110     110
# 28.0                         264           264     264        264     264
# 32.0                         242           242     242        242     242
# 36.0                         110           110     110        110     110
# 39.0                         154           154     154        154     154
# 42.0                         176           176     176        176     176
# 44.0                          44            44      44         44      44
# 57.0                         154           154     154        154     154
# 79.0                         231           231     231        231     231
# 83.0                         168           168     168        168     168
# 86.0                         105           105     105        105     105
# ...

# %% [markdown]
# # Test with Possesion #12

# %%
pos12 = df[df['possession'].isin([27.0, 28.0, 29.0])]

# %%
pos12_sorted = pos12.sort_values(by='timestamp', ascending=True)

# %%
import matplotlib.pyplot as plt

from src.animation import create_tracking_animation_from_df

# Filter to possession 12 (frames 2312–2510)
fig, anim = create_tracking_animation_from_df(
    pos12_sorted,
    match_id=2006551,
    save_path="possession_12_2006551.mp4",
    fps=10,
    interval=10,
)

plt.show()
# Out:
# Saving animation to possession_12_2006551.mp4...
# Animation saved!
