# %%
import pandas as pd
import numpy as np
import json
from pathlib import Path

# %%
creds_path = Path("creds") / "gdrive_folder.json"
with creds_path.open() as f:
    sb_data_path = json.load(f)

sb_data_folder_path = sb_data_path["statsbomb_data_folder_path"]

# %%
df_matches = pd.read_parquet(sb_data_folder_path + "/USLChampionship_2025_matches.parquet")

# %%
df_matches.head()
# Out:
#    match_id  match_date      kick_off             competition season  \
# 0   3985715  2025-07-16  23:30:00.000  USA - USL Championship   2025
# 1   3985850  2025-10-23  02:00:00.000  USA - USL Championship   2025
# 2   3985706  2025-07-12  23:00:00.000  USA - USL Championship   2025
# 3   3985803  2025-09-12  22:00:00.000  USA - USL Championship   2025
# 4   3985550  2025-03-22  21:00:00.000  USA - USL Championship   2025
#
#              home_team           away_team  home_score  away_score attendance  \
# 0    Hartford Athletic   Tampa Bay Rowdies         0.0         1.0       None
# 1  Sacramento Republic  Charleston Battery         1.0         0.0       None
# 2          Indy Eleven        Rhode Island         1.0         0.0       None
# 3         Lexington SC    Orange County SC         1.0         1.0       None
# 4    New Mexico United  El Paso Locomotive         1.0         0.0       None
#
#    ...            last_updated_360  match_week competition_stage  \
# ...

# %%
df_matches['match_id'].nunique()
# Out:
# 375

# %%
df_player_season = pd.read_parquet(sb_data_folder_path + "/USLChampionship_2025_player_season.parquet")

# %%
df_player_season.head()
# Out:
#    account_id  player_id        player_name  team_id       team_name  \
# 0        6040      34034      Alexis Souahy     1462     San Antonio
# 1        6040      41432  Nico Diago Gordon     8350    Monterey Bay
# 2        6040      90633     Harvey Neville     1467  Phoenix Rising
# 3        6040     218054    Stephen Carroll     2341    Detroit City
# 4        6040     141759     Joshua O'Brien     1427     Indy Eleven
#
#    competition_id  competition_name  season_id season_name  country_id  ...  \
# 0              89  USL Championship        315        2025          50  ...
# 1              89  USL Championship        315        2025         153  ...
# 2              89  USL Championship        315        2025         109  ...
# 3              89  USL Championship        315        2025         109  ...
# 4              89  USL Championship        315        2025         109  ...
#
#   player_season_fhalf_lbp_to_space_10_90  player_season_f3_lbp_to_space_10_90  \
# ...

# %%
df_player_season.columns.tolist()
# Out:
# ['account_id',
#  'player_id',
#  'player_name',
#  'team_id',
#  'team_name',
#  'competition_id',
#  'competition_name',
#  'season_id',
#  'season_name',
#  'country_id',
#  'birth_date',
#  'player_female',
#  'player_first_name',
#  'player_last_name',
#  'player_known_name',
#  'player_weight',
#  'player_height',
#  'player_season_minutes',
#  'player_season_np_xg_per_shot',
#  'player_season_np_xg_90',
#  'player_season_np_shots_90',
#  'player_season_goals_90',
#  'player_season_npga_90',
#  'player_season_xa_90',
#  'player_season_key_passes_90',
#  'player_season_op_key_passes_90',
#  'player_season_assists_90',
#  'player_season_through_balls_90',
#  'player_season_passes_into_box_90',
#  'player_season_op_passes_into_box_90',
#  'player_season_touches_inside_box_90',
#  'player_season_op_passes_into_and_touches_inside_box_90',
#  'player_season_tackles_90',
#  'player_season_interceptions_90',
#  'player_season_tackles_and_interceptions_90',
# ...

# %%
df_events = pd.read_parquet(
    sb_data_folder_path + "/USLChampionship_2025.parquet",
    engine="pyarrow",
)

# %%
df_events.head()
# Out:
#   50_50 bad_behaviour_card ball_receipt_outcome  \
# 0  None                NaN                  NaN
# 1  None                NaN                  NaN
# 2  None                NaN                  NaN
# 3  None                NaN                  NaN
# 4  None                NaN                  NaN
#
#   ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                           None             None            None
# 1                           None             None            None
# 2                           None             None            None
# 3                           None             None            None
# 4                           None             None            None
#
#   carry_end_location clearance_aerial_won clearance_body_part clearance_head  \
# 0               None                 None                 NaN           None
# 1               None                 None                 NaN           None
# ...

# %%
df_events.shape
# Out:
# (1164924, 136)

# %%
df_events.columns.tolist()
# Out:
# ['50_50',
#  'bad_behaviour_card',
#  'ball_receipt_outcome',
#  'ball_recovery_recovery_failure',
#  'block_deflection',
#  'block_offensive',
#  'carry_end_location',
#  'clearance_aerial_won',
#  'clearance_body_part',
#  'clearance_head',
#  'clearance_left_foot',
#  'clearance_right_foot',
#  'counterpress',
#  'dribble_no_touch',
#  'dribble_outcome',
#  'duel_outcome',
#  'duel_type',
#  'duration',
#  'foul_committed_advantage',
#  'foul_committed_card',
#  'foul_committed_offensive',
#  'foul_committed_type',
#  'foul_won_advantage',
#  'foul_won_defensive',
#  'goalkeeper_body_part',
#  'goalkeeper_end_location',
#  'goalkeeper_outcome',
#  'goalkeeper_position',
#  'goalkeeper_technique',
#  'goalkeeper_type',
#  'id',
#  'index',
#  'injury_stoppage_in_chain',
#  'interception_outcome',
#  'location',
#  'match_id',
#  'minute',
#  'miscontrol_aerial_won',
#  'obv_against_after',
#  'obv_against_before',
#  'obv_against_net',
#  'obv_for_after',
#  'obv_for_before',
# ...

# %%
df_events['match_id'].nunique()
# Out:
# 371
